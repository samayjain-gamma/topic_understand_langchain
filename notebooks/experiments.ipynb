# %%
print("hello workd")
# Out:
# hello workd

# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.11.14 (main, Feb 12 2026, 00:42:50) [Clang 21.1.4 ]
# /home/my/ai_projects/topic_understanding/.venv/bin/python

# %% [markdown]
# Research Work

# %%
from app.config import get_llm
from app.prompts import subquestion_prompt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from app.config import get_llm
#       2 from app.prompts import subquestion_prompt
#
# ModuleNotFoundError: No module named 'app'
